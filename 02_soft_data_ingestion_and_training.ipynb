# %%
pip install torch transformers
# Out:
# Requirement already satisfied: torch in ./.venv/lib/python3.14/site-packages (2.11.0)
# Requirement already satisfied: transformers in ./.venv/lib/python3.14/site-packages (5.8.1)
# Requirement already satisfied: filelock in ./.venv/lib/python3.14/site-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.venv/lib/python3.14/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in ./.venv/lib/python3.14/site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.14/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./.venv/lib/python3.14/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.14/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in ./.venv/lib/python3.14/site-packages (from torch) (2026.4.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in ./.venv/lib/python3.14/site-packages (from transformers) (1.14.0)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.14/site-packages (from transformers) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.14/site-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.14/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in ./.venv/lib/python3.14/site-packages (from transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in ./.venv/lib/python3.14/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in ./.venv/lib/python3.14/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in ./.venv/lib/python3.14/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in ./.venv/lib/python3.14/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in ./.venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: anyio in ./.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.15)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.14/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in ./.venv/lib/python3.14/site-packages (from typer->transformers) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.14/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in ./.venv/lib/python3.14/site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./.venv/lib/python3.14/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.14/site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.14/site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.14/site-packages (from jinja2->torch) (3.0.3)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
path = "sp500_headlines_2008_2024.csv"
headline_df = pd.read_csv(path).drop(columns=["CP"])
headline_df["aligned_date"] = pd.to_datetime(headline_df["Date"]) + pd.offsets.MonthBegin(1)
headline_df.sort_values("Date", inplace=True)
headline_df.head(20)
# Out:
#                                                 Title        Date aligned_date
# 0    JPMorgan Predicts 2008 Will Be "Nothing But Net"  2008-01-02   2008-02-01
# 1   Dow Tallies Biggest First-session-of-year Poin...  2008-01-02   2008-02-01
# 2                    2008 predictions for the S&P 500  2008-01-02   2008-02-01
# 3   U.S. Stocks Higher After Economic Data, Monsan...  2008-01-03   2008-02-01
# 4   U.S. Stocks Climb As Hopes Increase For More F...  2008-01-07   2008-02-01
# 5   How Investing in Intangibles -- Like Employee ...  2008-01-09   2008-02-01
# 6          Head And Shoulders Top Bodes Ill For Bulls  2008-01-09   2008-02-01
# 7   U.S. Stocks Zigzag Higher As Bernanke Speech S...  2008-01-10   2008-02-01
# 8   It's a Black Monday as stock markets tank in e...  2008-01-22   2008-02-01
# 9       U.S. Stocks Largely Recover From Early Plunge  2008-01-22   2008-02-01
# 10     U.S. Stocks Sink; Dow Off More Than 180 Points  2008-01-22   2008-02-01
# 11  Marriage - Tracy Collier and John Helvey | Com...  2008-01-22   2008-02-01
# 12  Former Connecticut hedge fund exec sues in son...  2008-01-29   2008-02-01
# 13                    Super Bowl Ideas That Can Score  2008-01-30   2008-02-01
# 14                   New challenges at retooled Janus  2008-02-01   2008-03-01
# 15             Stocks Tumble As Data Signal Recession  2008-02-05   2008-03-01
# 16        Satin PS3 to launch in Japan • The Register  2008-02-05   2008-03-01
# 17   The Flawed Fed Valuation Model - The Big Picture  2008-02-05   2008-03-01
# 18  U.S. Stocks Drop As AIG Discloses Doubts About...  2008-02-11   2008-03-01
# 19  U.S. Stocks Cut Losses In The Wake Of AIG Disc...  2008-02-11   2008-03-01

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis", model="ProsusAI/finbert")
# Out:
# Loading weights: 100%|██████████| 201/201 [00:00<00:00, 54180.92it/s]

# %%
headlines = headline_df["Title"].tolist()
classification = classifier(headlines, top_k=None)

# %%
pos_scores = []
neg_scores = []
neu_scores = []

for results in classification:
    score_dict = {result["label"]: result["score"] for result in results}
    pos_scores.append(score_dict.get("positive", 0))
    neg_scores.append(score_dict.get("negative", 0))
    neu_scores.append(score_dict.get("neutral", 0))

headline_df["Pos_Score"] = pos_scores
headline_df["Neg_Score"] = neg_scores
headline_df["Neu_Score"] = neu_scores

output_path = "sp500_headlines_2008_2024_with_sentiment.csv"
headline_df.to_csv(output_path, index=False)
headline_df.head(20)
# Out:
#                                                 Title        Date  \
# 0    JPMorgan Predicts 2008 Will Be "Nothing But Net"  2008-01-02
# 1   Dow Tallies Biggest First-session-of-year Poin...  2008-01-02
# 2                    2008 predictions for the S&P 500  2008-01-02
# 3   U.S. Stocks Higher After Economic Data, Monsan...  2008-01-03
# 4   U.S. Stocks Climb As Hopes Increase For More F...  2008-01-07
# 5   How Investing in Intangibles -- Like Employee ...  2008-01-09
# 6          Head And Shoulders Top Bodes Ill For Bulls  2008-01-09
# 7   U.S. Stocks Zigzag Higher As Bernanke Speech S...  2008-01-10
# 8   It's a Black Monday as stock markets tank in e...  2008-01-22
# 9       U.S. Stocks Largely Recover From Early Plunge  2008-01-22
# 10     U.S. Stocks Sink; Dow Off More Than 180 Points  2008-01-22
# 11  Marriage - Tracy Collier and John Helvey | Com...  2008-01-22
# 12  Former Connecticut hedge fund exec sues in son...  2008-01-29
# 13                    Super Bowl Ideas That Can Score  2008-01-30
# 14                   New challenges at retooled Janus  2008-02-01
# 15             Stocks Tumble As Data Signal Recession  2008-02-05
# 16        Satin PS3 to launch in Japan • The Register  2008-02-05
# 17   The Flawed Fed Valuation Model - The Big Picture  2008-02-05
# 18  U.S. Stocks Drop As AIG Discloses Doubts About...  2008-02-11
# 19  U.S. Stocks Cut Losses In The Wake Of AIG Disc...  2008-02-11
#
#    aligned_date  Pos_Score  Neg_Score  Neu_Score
# 0    2008-02-01   0.188399   0.604176   0.207425
# 1    2008-02-01   0.011426   0.962149   0.026425
# 2    2008-02-01   0.052938   0.122815   0.824247
# 3    2008-02-01   0.861627   0.064192   0.074181
# 4    2008-02-01   0.586567   0.165055   0.248378
# 5    2008-02-01   0.082773   0.014693   0.902534
# 6    2008-02-01   0.024102   0.843392   0.132506
# 7    2008-02-01   0.542340   0.282442   0.175218
# 8    2008-02-01   0.025481   0.926721   0.047798
# 9    2008-02-01   0.446016   0.516208   0.037776
# 10   2008-02-01   0.011590   0.966804   0.021606
# 11   2008-02-01   0.023489   0.068304   0.908207
# 12   2008-02-01   0.043178   0.766623   0.190199
# 13   2008-02-01   0.096287   0.016126   0.887587
# 14   2008-03-01   0.086783   0.020854   0.892363
# 15   2008-03-01   0.020091   0.924093   0.055815
# 16   2008-03-01   0.176424   0.010261   0.813315
# 17   2008-03-01   0.029818   0.424299   0.545883
# 18   2008-03-01   0.014849   0.926171   0.058980
# 19   2008-03-01   0.122544   0.854106   0.023349

# %%
headline_df = pd.read_csv("sp500_headlines_2008_2024_with_sentiment.csv", 
    parse_dates=["Date","aligned_date"])
headline_df
# Out:
#                                                    Title       Date  \
# 0       JPMorgan Predicts 2008 Will Be "Nothing But Net" 2008-01-02
# 1      Dow Tallies Biggest First-session-of-year Poin... 2008-01-02
# 2                       2008 predictions for the S&P 500 2008-01-02
# 3      U.S. Stocks Higher After Economic Data, Monsan... 2008-01-03
# 4      U.S. Stocks Climb As Hopes Increase For More F... 2008-01-07
# ...                                                  ...        ...
# 19122          REITs vs. Stocks: What Does the Data Say? 2024-03-04
# 19123  Nasdaq Index, Dow Jones, S&P 500 News: Futures... 2024-03-04
# 19124  Nasdaq 100, Dow Jones, S&P 500 News: Cautious ... 2024-03-04
# 19125  Bank of America boosts S&P 500 target to 5,400... 2024-03-04
# 19126  S&P 500 Gains and Losses Today: Tesla Shares T... 2024-03-04
#
#       aligned_date  Pos_Score  Neg_Score  Neu_Score
# 0       2008-02-01   0.188399   0.604176   0.207425
# 1       2008-02-01   0.011426   0.962149   0.026425
# 2       2008-02-01   0.052938   0.122815   0.824247
# 3       2008-02-01   0.861627   0.064192   0.074181
# 4       2008-02-01   0.586567   0.165055   0.248378
# ...            ...        ...        ...        ...
# 19122   2024-04-01   0.035319   0.142745   0.821936
# 19123   2024-04-01   0.045620   0.907880   0.046500
# 19124   2024-04-01   0.105398   0.267573   0.627029
# 19125   2024-04-01   0.157201   0.015896   0.826903
# 19126   2024-04-01   0.010004   0.971098   0.018898
#
# [19127 rows x 6 columns]

# %%
mean_sentiment = headline_df.groupby(["Date", "aligned_date"])[["Pos_Score", "Neg_Score", "Neu_Score"]].mean().reset_index()

# %% [markdown]
# We will aggregate these daily scores into a rolling 30-day sentiment index using an Exponential Moving Average (EMA) and create a "Neutrality Ratio" to cut through the noise of neutral financial journalism.
# - The Neutrality Ratio Filter: Financial headlines often state dry facts, causing FinBERT to output high "Neutral" probabilities. We have to filter this to show only directional bias.
#     - By calculating `Positive / (Positive + Negative)`, it isolates the directional bias by answering the question: Of the sentiment that actually took a stance, how much of it was positive?
# - EMA: Markets react to recent news much more violently than month-old news, so we use an EMA rather than an SMA to look at the score

# %%
mean_sentiment["Neutrality_Ratio"]= (mean_sentiment["Pos_Score"]/(mean_sentiment["Pos_Score"]+mean_sentiment["Neg_Score"])).fillna(0.5)
mean_sentiment["Pos_Score_30day_EMA"] = mean_sentiment["Pos_Score"].ewm(span=30, adjust=False).mean()
mean_sentiment["Neg_Score_30day_EMA"] = mean_sentiment["Neg_Score"].ewm(span=30, adjust=False).mean()
mean_sentiment["Neutrality_Ratio_30day_EMA"] = mean_sentiment["Neutrality_Ratio"].ewm(span=30, adjust=False).mean()
mean_sentiment.drop_duplicates(subset='aligned_date', keep='last',inplace=True)
mean_sentiment
# Out:
#            Date aligned_date  Pos_Score  Neg_Score  Neu_Score  \
# 7    2008-01-30   2008-02-01   0.096287   0.016126   0.887587
# 14   2008-02-29   2008-03-01   0.020833   0.947423   0.031744
# 20   2008-03-27   2008-04-01   0.011984   0.959217   0.028799
# 27   2008-04-25   2008-05-01   0.338670   0.293752   0.367578
# 37   2008-05-29   2008-06-01   0.072870   0.902726   0.024404
# ...         ...          ...        ...        ...        ...
# 3443 2023-11-30   2023-12-01   0.390927   0.294099   0.314974
# 3463 2023-12-29   2024-01-01   0.286357   0.419801   0.293842
# 3484 2024-01-31   2024-02-01   0.134494   0.377243   0.488262
# 3504 2024-02-29   2024-03-01   0.335937   0.273130   0.390934
# 3506 2024-03-04   2024-04-01   0.257560   0.414888   0.327552
#
#       Neutrality_Ratio  Pos_Score_30day_EMA  Neg_Score_30day_EMA  \
# 7             0.856544             0.164449             0.481827
# 14            0.021516             0.124942             0.459353
# 20            0.012340             0.142335             0.497481
# 27            0.535513             0.139617             0.478218
# 37            0.074693             0.157693             0.448432
# ...                ...                  ...                  ...
# 3443          0.570675             0.288294             0.368613
# 3463          0.405514             0.320061             0.304784
# 3484          0.262819             0.306004             0.343688
# 3504          0.551560             0.341223             0.302135
# 3506          0.383019             0.347473             0.303952
#
#       Neutrality_Ratio_30day_EMA
# 7                       0.266188
# 14                      0.295600
# 20                      0.299145
# 27                      0.310837
# 37                      0.363876
# ...                          ...
# 3443                    0.436345
# 3463                    0.513559
# 3484                    0.463749
# 3504                    0.523062
# 3506                    0.525682
#
# [195 rows x 9 columns]

# %%
from fredapi import Fred
from dotenv import load_dotenv
import os
load_dotenv()
FRED_API_KEY = os.getenv("FRED_API_KEY")
fred_auth = fred = Fred(api_key=FRED_API_KEY)
recession_data = pd.DataFrame(fred_auth.get_series("USREC")).reset_index().rename(columns={"index": "aligned_date", 0: "recession"})
recession_data = recession_data[recession_data['aligned_date'] >= pd.to_datetime('2001-01-01')]
recession_data["period_rolling_recession"]= recession_data["recession"].rolling(window=6, min_periods=1).max().shift(-6)
recession_data[["aligned_date","period_rolling_recession"]].dropna()
# Out:
#      aligned_date  period_rolling_recession
# 1753   2001-01-01                       1.0
# 1754   2001-02-01                       1.0
# 1755   2001-03-01                       1.0
# 1756   2001-04-01                       1.0
# 1757   2001-05-01                       1.0
# ...           ...                       ...
# 2046   2025-06-01                       0.0
# 2047   2025-07-01                       0.0
# 2048   2025-08-01                       0.0
# 2049   2025-09-01                       0.0
# 2050   2025-10-01                       0.0
#
# [298 rows x 2 columns]

# %%
feature_data = pd.merge(
    mean_sentiment, 
    recession_data[["aligned_date","period_rolling_recession"]].dropna(), 
    on='aligned_date', 
    how='left'
)
feature_data.drop(columns=["Date","Pos_Score","Neg_Score","Neu_Score","Neutrality_Ratio"], inplace= True)
feature_data = feature_data.dropna()
feature_data.dropna()
output_path = "sentiment_training_data_features.csv"
feature_data.to_csv(output_path, index=False)

# %% [markdown]
# At this point we've running into an issue: The Mismatched History Problem. There is a different period of data sets that is available to us.
#
# The "Test Set" Golden Rule
# - In a head-to-head evaluation or an ensemble, the models are competing to see how they handle "unseen" data.
# - We have to make sure they test on the same unseen data to ensure a fair test.
#
# To tackle this:
# - Macro Model: Trained on 2001–2015. Tested on 2016–Present.
# - Sentiment Model: Train on 2008–2015. Test on 2016–Present.

# %%
pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in ./.venv/lib/python3.14/site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in ./.venv/lib/python3.14/site-packages (from lightgbm) (2.4.4)
# Requirement already satisfied: scipy in ./.venv/lib/python3.14/site-packages (from lightgbm) (1.17.1)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, roc_auc_score
phase_1_split_aligned_date = "2016-07-01"
training_data = feature_data[feature_data["aligned_date"]<phase_1_split_aligned_date] 
testing_data = feature_data[feature_data["aligned_date"]>=phase_1_split_aligned_date]
training_x = training_data.drop(columns=['period_rolling_recession','aligned_date'])
training_y = training_data['period_rolling_recession']
testing_x = testing_data.drop(columns=['period_rolling_recession','aligned_date'])
testing_y = testing_data['period_rolling_recession']

ratio = (training_y == 0).sum() / (training_y == 1).sum()
print(f"Calculated scale_pos_weight: {ratio:.2f}")
# Out:
# Calculated scale_pos_weight: 5.31

# %%
lightgbm_model = LGBMClassifier(
    scale_pos_weight=ratio,
    n_estimators=100,
    learning_rate=0.05,
    random_state=42
)

# %%
# mac conflict
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
lightgbm_model.fit(training_x, training_y)
y_lightgbm_pred = lightgbm_model.predict(testing_x)
# Out:
# [LightGBM] [Info] Number of positive: 16, number of negative: 85
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000304 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 105
# [LightGBM] [Info] Number of data points in the train set: 101, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.158416 -> initscore=-1.670063
# [LightGBM] [Info] Start training from score -1.670063
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
print("\nClassification Report for LightGBM:")
print(classification_report(testing_y, y_lightgbm_pred))
# Out:
# Classification Report for LightGBM:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.71      0.79        87
#          1.0       0.00      0.00      0.00         7
#
#     accuracy                           0.66        94
#    macro avg       0.45      0.36      0.40        94
# weighted avg       0.83      0.66      0.74        94

# %%
y_lightgbm_probs_all = lightgbm_model.predict_proba(testing_x)
y_recession_probs = y_lightgbm_probs_all [:, 1]
lightgbm_proba_table = testing_data[['aligned_date']].copy()
lightgbm_proba_table['y_recession_prob'] = y_recession_probs
lightgbm_proba_table = pd.merge(
    lightgbm_proba_table, 
    recession_data, 
    on='aligned_date', 
    how='left'
)

lightgbm_proba_table['change'] = lightgbm_proba_table['recession'].diff()
starts = lightgbm_proba_table[lightgbm_proba_table['change'] == 1]['aligned_date'].tolist()
ends = lightgbm_proba_table[lightgbm_proba_table['change'] == -1]['aligned_date'].tolist()
if lightgbm_proba_table['recession'].iloc[0] == 1:
    starts.insert(0, lightgbm_proba_table['aligned_date'].iloc[0])
if lightgbm_proba_table['recession'].iloc[-1] == 1:
    ends.append(lightgbm_proba_table['aligned_date'].iloc[-1])
    
from matplotlib import pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(lightgbm_proba_table['aligned_date'], lightgbm_proba_table['y_recession_prob'], 
         label='XGBoost Recession Probability', color='blue')

for s, e in zip(starts, ends):
    plt.axvspan(s, e, color='gray', alpha=0.3, label='Actual NBER Recession')
plt.title('LightGBM Predicted Recession Probability Over Time')
plt.xlabel('Date')
plt.ylabel('Predicted Probability of Recession')
plt.legend()

# %%
lightgbm_proba_table.head(20)
auc = roc_auc_score(testing_y, lightgbm_proba_table["y_recession_prob"])
print(f"ROC-AUC Score: {auc:.4f}")
# Out:
# ROC-AUC Score: 0.3005

# %%
import joblib
joblib.dump(lightgbm_model, 'soft_model.joblib')
# Out:
# ['soft_model.joblib']

# %% [markdown]
# ### Reconducting this process by aggregating by week rather than by month

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt

# ---------------------------------------------------------
# SPLIT DATA INTO TRAIN AND TEST SETS
# ---------------------------------------------------------
phase_1_split_aligned_date = "2016-07-01"

# Use the new 'aligned_week' for the split instead of aligned_date
training_data = feature_data[feature_data["aligned_week"] < phase_1_split_aligned_date] 
testing_data = feature_data[feature_data["aligned_week"] >= phase_1_split_aligned_date]

# Drop the target variable and the date column from the feature sets
training_x = training_data.drop(columns=['period_rolling_recession', 'aligned_week'])
training_y = training_data['period_rolling_recession']

testing_x = testing_data.drop(columns=['period_rolling_recession', 'aligned_week'])
testing_y = testing_data['period_rolling_recession']

# Calculate class imbalance ratio for LightGBM
ratio = (training_y == 0).sum() / (training_y == 1).sum()
print(f"Calculated scale_pos_weight: {ratio:.2f}")

# ---------------------------------------------------------
# TRAIN THE LIGHTGBM MODEL
# ---------------------------------------------------------
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

lightgbm_model = LGBMClassifier(
    scale_pos_weight=ratio,
    n_estimators=100,
    learning_rate=0.05,
    random_state=42
)

lightgbm_model.fit(training_x, training_y)

# ---------------------------------------------------------
# EVALUATE THE MODEL
# ---------------------------------------------------------
y_lightgbm_pred = lightgbm_model.predict(testing_x)

print("\nClassification Report for LightGBM:")
print(classification_report(testing_y, y_lightgbm_pred))

y_lightgbm_probs_all = lightgbm_model.predict_proba(testing_x)
y_recession_probs = y_lightgbm_probs_all[:, 1]

auc = roc_auc_score(testing_y, y_recession_probs)
print(f"ROC-AUC Score: {auc:.4f}")

# ---------------------------------------------------------
# PREPARE DATA FOR PLOTTING
# ---------------------------------------------------------

lightgbm_proba_table = testing_data[['aligned_week']].copy()
lightgbm_proba_table['y_recession_prob'] = y_recession_probs

lightgbm_proba_table['month_start'] = lightgbm_proba_table['aligned_week'].dt.to_period('M').dt.start_time

lightgbm_proba_table = pd.merge(
    lightgbm_proba_table, 
    recession_data, 
    on='month_start', 
    how='left'
)

lightgbm_proba_table['change'] = lightgbm_proba_table['recession'].diff()

starts = lightgbm_proba_table[lightgbm_proba_table['change'] == 1]['aligned_week'].tolist()
ends = lightgbm_proba_table[lightgbm_proba_table['change'] == -1]['aligned_week'].tolist()

if lightgbm_proba_table['recession'].iloc[0] == 1:
    starts.insert(0, lightgbm_proba_table['aligned_week'].iloc[0])
if lightgbm_proba_table['recession'].iloc[-1] == 1:
    ends.append(lightgbm_proba_table['aligned_week'].iloc[-1])

# ---------------------------------------------------------
# PLOT THE RESULTS
# ---------------------------------------------------------
plt.figure(figsize=(12, 6))

plt.plot(lightgbm_proba_table['aligned_week'], lightgbm_proba_table['y_recession_prob'], 
         label='LightGBM Recession Probability', color='blue')

for i, (s, e) in enumerate(zip(starts, ends)):
    label = 'Actual NBER Recession' if i == 0 else ""
    plt.axvspan(s, e, color='gray', alpha=0.3, label=label)

plt.title('LightGBM Predicted Recession Probability Over Time (Weekly Data)')
plt.xlabel('Date')
plt.ylabel('Predicted Probability of Recession')
plt.legend()
plt.show()
# Out:
# Calculated scale_pos_weight: 5.32
# [LightGBM] [Info] Number of positive: 69, number of negative: 367
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000258 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 438
# [LightGBM] [Info] Number of data points in the train set: 436, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.158257 -> initscore=-1.671255
# [LightGBM] [Info] Start training from score -1.671255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Classification Report for LightGBM:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.68      0.78       369
#          1.0       0.08      0.32      0.13        31
#
#     accuracy                           0.65       400
#    macro avg       0.50      0.50      0.45       400
# weighted avg       0.86      0.65      0.73       400
#
# ROC-AUC Score: 0.4427

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt
import pandas as pd

# ---------------------------------------------------------
# TRAIN THE LOGISTIC REGRESSION MODEL
# ---------------------------------------------------------
log_reg_model = make_pipeline(
    StandardScaler(),
    LogisticRegression(class_weight='balanced', random_state=42)
)

log_reg_model.fit(training_x, training_y)
y_log_pred = log_reg_model.predict(testing_x)

print("\nClassification Report for Logistic Regression:")
print(classification_report(testing_y, y_log_pred))

y_log_probs_all = log_reg_model.predict_proba(testing_x)
y_recession_probs = y_log_probs_all[:, 1]

auc = roc_auc_score(testing_y, y_recession_probs)
print(f"ROC-AUC Score: {auc:.4f}")

log_proba_table = testing_data[['aligned_week']].copy()
log_proba_table['y_recession_prob'] = y_recession_probs

log_proba_table['month_start'] = log_proba_table['aligned_week'].dt.to_period('M').dt.start_time

log_proba_table = pd.merge(
    log_proba_table, 
    recession_data, 
    on='month_start', 
    how='left'
)

log_proba_table['change'] = log_proba_table['recession'].diff()

starts = log_proba_table[log_proba_table['change'] == 1]['aligned_week'].tolist()
ends = log_proba_table[log_proba_table['change'] == -1]['aligned_week'].tolist()

# Handle edge cases (recession active at the very start or end of the data block)
if log_proba_table['recession'].iloc[0] == 1:
    starts.insert(0, log_proba_table['aligned_week'].iloc[0])
if log_proba_table['recession'].iloc[-1] == 1:
    ends.append(log_proba_table['aligned_week'].iloc[-1])

# ---------------------------------------------------------
# PLOT THE RESULTS
# ---------------------------------------------------------
plt.figure(figsize=(12, 6))

plt.plot(log_proba_table['aligned_week'], log_proba_table['y_recession_prob'], 
         label='Logistic Regression Recession Probability', color='purple', linewidth=2)
for i, (s, e) in enumerate(zip(starts, ends)):
    label = 'Actual NBER Recession' if i == 0 else ""
    plt.axvspan(s, e, color='gray', alpha=0.3, label=label)

plt.title('Logistic Regression Predicted Recession Probability Over Time (Weekly)')
plt.xlabel('Date')
plt.ylabel('Predicted Probability of Recession')
plt.legend()
plt.show()
# Out:
# Classification Report for Logistic Regression:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.62      0.74       369
#          1.0       0.05      0.23      0.08        31
#
#     accuracy                           0.59       400
#    macro avg       0.48      0.42      0.41       400
# weighted avg       0.84      0.59      0.69       400
#
# ROC-AUC Score: 0.3544
